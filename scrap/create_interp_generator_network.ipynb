# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
from advertorch.attacks import GradientSignAttack, CarliniWagnerL2Attack, PGDAttack
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import time
import sys
sys.path.append("..")
import utils.adv_ex_utils as aus
import utils.interp_generators as igs
import utils.utils as utils
from utils.models import LeNet, DDNet, SimpleCNN
from utils.data_loaders import DataLoader

# makes default tensor a CUDA tensor so GPU can be used
device = torch.device(2 if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
if device != 'cpu':
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
def train():
    start = time.time()
    net.train()
    
    for batch_idx, (samples, labels) in enumerate(train_loader):
        # sends to GPU, i.e. essentially converts from torch.FloatTensor to torch.cuda.FloatTensor
        samples, labels = samples.to(device), labels.to(device)
        # replace each sample with PGD perturbed sample
        samples, labels = aus.generate_adv_exs(samples, labels, adversary)
                
        optimizer.zero_grad()
        output = net(samples)
        loss = F.cross_entropy(output, labels)
        loss.backward()
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            j = utils.avg_norm_jacobian(net, samples, output.shape[1], tr, for_loss=False)
            i,_ = utils.norm_diff_interp(net, samples, labels, dataset, scale=.15, for_loss=False)
            print(f'\tLoss: {loss.item():.6f}, Average norm of Jacobian: {j:.6f}, Norm of difference in interpretations: {i:.6f}')
    
    finish = time.time()
    print(f'Time to complete epoch: {finish - start:.1f} seconds')

# %%
def test():
    net.eval()
    adv_test_loss = 0
    correct = 0
    
    for samples, labels in test_loader:
        samples, labels = samples.to(device), labels.to(device)
        samples, labels = aus.generate_adv_exs(samples, labels, adversary)
        
        output = net(samples)
        adv_test_loss += F.cross_entropy(output, labels)
        
        # output is a tensor, .data retrieves its data, max returns the index of the highest valued element
        preds = output.data.max(1, keepdim=True)[1]
        correct += preds.eq(labels.data.view_as(preds)).sum().item()
                
    adv_test_loss /= len(test_loader.dataset)
    adv_test_accuracy = 100. * float(correct / len(test_loader.dataset))
    
    print(f'PGD-perturbed test set accuracy: ({adv_test_accuracy:.2f}%)')

# %%
dataset = 'MNIST'

dl = DataLoader(dataset=dataset, augment=False, path='../data')
train_loader = dl.train_loader
test_loader = dl.test_loader
tr_batch_size = dl.tr_batch_size
te_batch_size = dl.te_batch_size

# matrices used to calculate norm of jacobian and 
# norm of difference between interpretations
tr = utils.bp_matrix(tr_batch_size, 10)
te = utils.bp_matrix(te_batch_size, 10)

# training details
n_epochs = 15
log_interval = 200
torch.manual_seed(7)

# dictionary to record each model's training/testing stats
performance = {}

# instantiate model and optimizer
net = SimpleCNN()
net_name = f'../trained_models/MNIST/interp_generators/simplecnn_pgd_eps1.5_niter40_epsiter.05_ord2_epochs30'
net.load_state_dict(torch.load(net_name))
optimizer = optim.SGD(net.parameters(), lr=.01, momentum=.9)
lr_decayer = StepLR(optimizer, step_size=10, gamma=0.1)

# make model CUDA enabled and define GPU/device to use
net.cuda()

# define adversary to train against if needed
adversary = PGDAttack(predict=net, loss_fn=F.cross_entropy, eps=1.5, 
                      nb_iter=40, eps_iter=0.05, rand_init=True, 
                      clip_min=0., clip_max=1., ord=2, targeted=False)

# %%
for epoch in range(1, n_epochs + 1):
    print(f'Epoch #{epoch}')
    train()
    test()
    lr_decayer.step()
# Out:
# Epoch #1
# 	Loss: 1.652884, Average norm of Jacobian: 0.216562, Norm of difference in interpretations: 31.000843
# 	Loss: 1.789160, Average norm of Jacobian: 0.280221, Norm of difference in interpretations: 28.133446
# 	Loss: 1.713718, Average norm of Jacobian: 0.012917, Norm of difference in interpretations: 31.478661
# 	Loss: 1.763574, Average norm of Jacobian: 0.117077, Norm of difference in interpretations: 30.162430
# 	Loss: 1.656541, Average norm of Jacobian: 0.233692, Norm of difference in interpretations: 31.451622
# Time to complete epoch: 143.8 seconds
# PGD-perturbed test set accuracy: (75.46%)
# Epoch #2
# 	Loss: 1.732963, Average norm of Jacobian: 0.396023, Norm of difference in interpretations: 30.866264
# 	Loss: 1.695391, Average norm of Jacobian: 0.288273, Norm of difference in interpretations: 30.926460
# 	Loss: 1.663254, Average norm of Jacobian: 0.314258, Norm of difference in interpretations: 32.695797
# 	Loss: 1.645886, Average norm of Jacobian: 0.253915, Norm of difference in interpretations: 33.897770
# 	Loss: 1.649861, Average norm of Jacobian: 0.362309, Norm of difference in interpretations: 33.162857
# Time to complete epoch: 160.1 seconds
# PGD-perturbed test set accuracy: (75.57%)
# Epoch #3
# 	Loss: 1.780791, Average norm of Jacobian: 0.061648, Norm of difference in interpretations: 33.517788
# 	Loss: 1.774153, Average norm of Jacobian: 0.130765, Norm of difference in interpretations: 32.147491
# 	Loss: 1.612335, Average norm of Jacobian: 0.244320, Norm of difference in interpretations: 36.228729
# 	Loss: 1.679145, Average norm of Jacobian: 0.162839, Norm of difference in interpretations: 33.478233
# 	Loss: 1.613557, Average norm of Jacobian: 0.273161, Norm of difference in interpretations: 34.564175
# Time to complete epoch: 151.2 seconds
# PGD-perturbed test set accuracy: (75.97%)
# Epoch #4
# 	Loss: 1.739824, Average norm of Jacobian: 0.267875, Norm of difference in interpretations: 33.014641
# 	Loss: 1.756140, Average norm of Jacobian: 0.222671, Norm of difference in interpretations: 31.939533
# 	Loss: 1.773860, Average norm of Jacobian: 0.182432, Norm of difference in interpretations: 33.069332
# 	Loss: 1.698842, Average norm of Jacobian: 0.228736, Norm of difference in interpretations: 35.066254
# 	Loss: 1.739761, Average norm of Jacobian: 0.274166, Norm of difference in interpretations: 31.986313
# Time to complete epoch: 143.6 seconds
# PGD-perturbed test set accuracy: (75.95%)
# Epoch #5
# 	Loss: 1.593656, Average norm of Jacobian: 0.329723, Norm of difference in interpretations: 35.410233
# 	Loss: 1.686177, Average norm of Jacobian: 0.137358, Norm of difference in interpretations: 35.331013
# 	Loss: 1.846008, Average norm of Jacobian: 0.566394, Norm of difference in interpretations: 31.735588
# 	Loss: 1.726413, Average norm of Jacobian: 0.134552, Norm of difference in interpretations: 36.421249
# 	Loss: 1.663299, Average norm of Jacobian: 0.391044, Norm of difference in interpretations: 34.529190
# Time to complete epoch: 162.8 seconds
# PGD-perturbed test set accuracy: (76.00%)
# Epoch #6
# 	Loss: 1.687848, Average norm of Jacobian: 0.085135, Norm of difference in interpretations: 35.678516
# 	Loss: 1.675859, Average norm of Jacobian: 0.456739, Norm of difference in interpretations: 36.852821
# 	Loss: 1.690615, Average norm of Jacobian: 0.086790, Norm of difference in interpretations: 33.632748
# 	Loss: 1.760868, Average norm of Jacobian: 0.155355, Norm of difference in interpretations: 33.896843
# 	Loss: 1.717937, Average norm of Jacobian: 0.110895, Norm of difference in interpretations: 35.191101
# Time to complete epoch: 108.0 seconds
# PGD-perturbed test set accuracy: (75.93%)
# Epoch #7
# 	Loss: 1.729337, Average norm of Jacobian: 0.111310, Norm of difference in interpretations: 39.082130
# 	Loss: 1.663797, Average norm of Jacobian: 0.302969, Norm of difference in interpretations: 35.044086
# 	Loss: 1.632693, Average norm of Jacobian: 0.231311, Norm of difference in interpretations: 37.942921
# 	Loss: 1.676225, Average norm of Jacobian: 0.408373, Norm of difference in interpretations: 36.007286
# 	Loss: 1.808097, Average norm of Jacobian: 0.314148, Norm of difference in interpretations: 34.655376
# Time to complete epoch: 105.5 seconds
# PGD-perturbed test set accuracy: (76.07%)
# Epoch #8
# 	Loss: 1.758688, Average norm of Jacobian: 0.382515, Norm of difference in interpretations: 36.109669
# 	Loss: 1.805617, Average norm of Jacobian: 0.334916, Norm of difference in interpretations: 33.254856
# 	Loss: 1.638704, Average norm of Jacobian: 0.134326, Norm of difference in interpretations: 38.248116
# 	Loss: 1.649718, Average norm of Jacobian: 0.228847, Norm of difference in interpretations: 36.692719
# 	Loss: 1.701536, Average norm of Jacobian: 0.087535, Norm of difference in interpretations: 37.178375
# Time to complete epoch: 152.0 seconds
# PGD-perturbed test set accuracy: (76.21%)
# Epoch #9
# 	Loss: 1.756935, Average norm of Jacobian: 0.481783, Norm of difference in interpretations: 33.155491
# 	Loss: 1.710604, Average norm of Jacobian: 0.117104, Norm of difference in interpretations: 37.339336
# 	Loss: 1.662228, Average norm of Jacobian: 0.321475, Norm of difference in interpretations: 37.466721
# 	Loss: 1.700042, Average norm of Jacobian: 0.052099, Norm of difference in interpretations: 36.127583
# 	Loss: 1.736798, Average norm of Jacobian: 0.273803, Norm of difference in interpretations: 35.264778
# Time to complete epoch: 133.9 seconds
# PGD-perturbed test set accuracy: (76.00%)
# Epoch #10
# 	Loss: 1.680746, Average norm of Jacobian: 0.321135, Norm of difference in interpretations: 38.973675
# 	Loss: 1.671399, Average norm of Jacobian: 0.817120, Norm of difference in interpretations: 38.820839
# 	Loss: 1.675252, Average norm of Jacobian: 0.209355, Norm of difference in interpretations: 37.086025
# 	Loss: 1.623498, Average norm of Jacobian: 0.207077, Norm of difference in interpretations: 36.459427
# 	Loss: 1.733968, Average norm of Jacobian: 0.301031, Norm of difference in interpretations: 39.313538
# Time to complete epoch: 153.6 seconds
# PGD-perturbed test set accuracy: (76.22%)
# Epoch #11
# 	Loss: 1.722344, Average norm of Jacobian: 0.124516, Norm of difference in interpretations: 38.531506
# 	Loss: 1.674853, Average norm of Jacobian: 0.446406, Norm of difference in interpretations: 39.443233
# 	Loss: 1.768076, Average norm of Jacobian: 0.208118, Norm of difference in interpretations: 37.757477
# 	Loss: 1.735678, Average norm of Jacobian: 0.277071, Norm of difference in interpretations: 37.868557
# 	Loss: 1.622703, Average norm of Jacobian: 0.051128, Norm of difference in interpretations: 38.735687
# Time to complete epoch: 152.3 seconds
# PGD-perturbed test set accuracy: (76.39%)
# Epoch #12
# 	Loss: 1.707139, Average norm of Jacobian: 0.186837, Norm of difference in interpretations: 37.445877
# 	Loss: 1.691507, Average norm of Jacobian: 0.300071, Norm of difference in interpretations: 37.019394
# 	Loss: 1.621099, Average norm of Jacobian: 0.351836, Norm of difference in interpretations: 40.001598
# 	Loss: 1.651185, Average norm of Jacobian: 0.261286, Norm of difference in interpretations: 39.111530
# 	Loss: 1.602817, Average norm of Jacobian: 0.239049, Norm of difference in interpretations: 37.931442
# Time to complete epoch: 140.3 seconds
# PGD-perturbed test set accuracy: (76.52%)
# Epoch #13
# 	Loss: 1.722064, Average norm of Jacobian: 0.129247, Norm of difference in interpretations: 36.632793
# 	Loss: 1.711015, Average norm of Jacobian: 0.483899, Norm of difference in interpretations: 36.920872
# 	Loss: 1.696157, Average norm of Jacobian: 0.238459, Norm of difference in interpretations: 39.594280
# 	Loss: 1.603217, Average norm of Jacobian: 0.211537, Norm of difference in interpretations: 38.006569
# 	Loss: 1.605839, Average norm of Jacobian: 0.340997, Norm of difference in interpretations: 39.411530
# Time to complete epoch: 146.3 seconds
# PGD-perturbed test set accuracy: (76.50%)
# Epoch #14
# 	Loss: 1.596299, Average norm of Jacobian: 0.263320, Norm of difference in interpretations: 39.196159
# 	Loss: 1.700057, Average norm of Jacobian: 0.415008, Norm of difference in interpretations: 36.896358
# 	Loss: 1.699477, Average norm of Jacobian: 0.196533, Norm of difference in interpretations: 38.967724
# 	Loss: 1.745865, Average norm of Jacobian: 0.151835, Norm of difference in interpretations: 38.538612
# 	Loss: 1.621021, Average norm of Jacobian: 0.400273, Norm of difference in interpretations: 39.148720
# Time to complete epoch: 147.7 seconds
# PGD-perturbed test set accuracy: (76.58%)
# Epoch #15
# 	Loss: 1.691168, Average norm of Jacobian: 0.192356, Norm of difference in interpretations: 39.760277
# 	Loss: 1.675072, Average norm of Jacobian: 0.299053, Norm of difference in interpretations: 38.620682
# 	Loss: 1.654040, Average norm of Jacobian: 0.260783, Norm of difference in interpretations: 37.533630
# 	Loss: 1.735862, Average norm of Jacobian: 0.287387, Norm of difference in interpretations: 37.595795
# 	Loss: 1.726114, Average norm of Jacobian: 0.098688, Norm of difference in interpretations: 36.820198
# Time to complete epoch: 129.8 seconds
# PGD-perturbed test set accuracy: (76.59%)

# %%
torch.save(net.state_dict(), f'../trained_models/MNIST/interp_generators/simplecnn_pgd_eps1.5_niter40_epsiter.05_ord2_epochs45')
